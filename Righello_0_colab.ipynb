# %%
# !pip install pyzipper
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 34.6 MB/s eta 0:00:00
# ...

# %%
url = 'https://github.com/crippadan/WIZ016-GA01_Righello/raw/refs/heads/main/ruler.py'

import urllib.request
urllib.request.urlretrieve(url, "ruler.py")
from ruler import Ruler
# !rm ruler.py

# %%
from ruler import Ruler

# %%
game = Ruler(pw='...')
game.play()
# Out:
# Output()
# Output()
# Text(value='', placeholder='Scrivi qui...')
